# %% [markdown]
# **PANDAS**
# **Series**

# %%
import pandas as pd
import numpy as np

# %%
mydata=[1,2,3]
myindex=['a','b','c']
myser=pd.Series(mydata)
myser
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
myser=pd.Series(mydata,myindex)
myser
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
dictionary={'a':1, 'k':11, 'z':26}
mydict=pd.Series(dictionary)
mydict
# Out:
# a     1
# k    11
# z    26
# dtype: int64

# %%
print(myser[2])
print(mydict['a'])
print(mydict['z'])
print(mydict.keys())
# Out:
# 3
# 1
# 26
# Index(['a', 'k', 'z'], dtype='object')
# C:\Users\balaj\AppData\Local\Temp\ipykernel_11728\8530049.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(myser[2])

# %%
pwd
# Out:
# 'c:\\Users\\balaj\\Desktop\\QuantumCona\\AIML_Practice\\PracticePandas_VSCode'

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 7CD6-3D0D
#
#  Directory of c:\Users\balaj\Desktop\QuantumCona\AIML_Practice\PracticePandas_VSCode
#
# 12/19/2025  12:48 PM    <DIR>          .
# 12/19/2025  12:47 PM    <DIR>          ..
# 12/19/2025  02:11 PM             3,497 pandas_practice1.ipynb
#                1 File(s)          3,497 bytes
#                2 Dir(s)  14,153,752,576 bytes free

# %% [markdown]
# **DataFrames**

# %%
df=pd.read_csv("tips.csv")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df.columns      #to retrieve the columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %%
df.index    #it tells the index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df.head(3)      #First 3 columns(default 5)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458

# %%
df.tail(5)      #Last 7 columns default(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name         CC Number Payment ID
# 239    Michael Avila  5296068606052842    Sat2657
# 240   Monica Sanders  3506806155565404    Sat1766
# 241       Keith Wong  6011891618747196    Sat3880
# 242     Dennis Dixon     4375220550950      Sat17
# 243  Michelle Hardin  3511451626698139    Thur672

# %%
df.info()       #To see the table structure
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
df.describe()       #It gives the Statistical Info of the table
df.describe().transpose()       #Transpose of describe table
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563496e+15  2.369340e+15  6.040679e+10
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040731e+13  3.525318e+15  4.553675e+15  6.596454e+15

# %%
df['total_bill']        #Selecting a Single column
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
type(df["total_bill"])
# Out:
# pandas.core.series.Series

# %%
df[['total_bill','tip']]            #for multiple cols must use 2 square Brackets
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
#Creating a New Column
df['tip_percentage']=100*df['tip']/df['total_bill']

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  tip_percentage
# 0  Christy Cunningham  3560325168603410    Sun2959        5.944673
# 1      Douglas Tucker  4478071379779230    Sun4608       16.054159
# 2      Travis Walters  6011812112971322    Sun4458       16.658734
# 3    Nathaniel Harris  4676137647685994    Sun5260       13.978041
# 4        Tonya Carter  4832732618637221    Sun2251       14.680765

# %%
df['price_per_person'] = df['total_bill'] / df['size']

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
# 5       25.29  4.71    Male     No  Sun  Dinner     4              6.32
# 6        8.77  2.00    Male     No  Sun  Dinner     2              4.38
# 7       26.88  3.12    Male     No  Sun  Dinner     4              6.72
# 8       15.04  1.96    Male     No  Sun  Dinner     2              7.52
# 9       14.78  3.23    Male     No  Sun  Dinner     2              7.39
#
#            Payer Name         CC Number Payment ID  tip_percentage
# 0  Christy Cunningham  3560325168603410    Sun2959        5.944673
# ...

# %%
#To round off after decimal
df['price_per_person']=np.round(df['price_per_person'],1)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2               8.5
# 1       10.34  1.66    Male     No  Sun  Dinner     3               3.4
# 2       21.01  3.50    Male     No  Sun  Dinner     3               7.0
# 3       23.68  3.31    Male     No  Sun  Dinner     2              11.8
# 4       24.59  3.61  Female     No  Sun  Dinner     4               6.2
#
#            Payer Name         CC Number Payment ID  tip_percentage
# 0  Christy Cunningham  3560325168603410    Sun2959        5.944673
# 1      Douglas Tucker  4478071379779230    Sun4608       16.054159
# 2      Travis Walters  6011812112971322    Sun4458       16.658734
# 3    Nathaniel Harris  4676137647685994    Sun5260       13.978041
# 4        Tonya Carter  4832732618637221    Sun2251       14.680765

# %%
#Removing Columns
df=df.drop('tip_percentage',axis=1)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2               8.5
# 1       10.34  1.66    Male     No  Sun  Dinner     3               3.4
# 2       21.01  3.50    Male     No  Sun  Dinner     3               7.0
# 3       23.68  3.31    Male     No  Sun  Dinner     2              11.8
# 4       24.59  3.61  Female     No  Sun  Dinner     4               6.2
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df.set_index('Payment ID')      #Setting Payment ID as Index
# Out:
#             index  total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959         0       16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608         1       10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458         2       21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260         3       23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251         4       24.59  3.61  Female     No   Sun  Dinner     4
# ...           ...         ...   ...     ...    ...   ...     ...   ...
# Sat2657       239       29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766       240       27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880       241       22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17         242       17.82  1.75    Male     No   Sat  Dinner     2
# Thur672       243       18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# ...

# %%
df
# Out:
#      Payment ID  total_bill smoker   day    time  size  price_per_person  \
# tip
# 1.01    Sun2959       16.99     No   Sun  Dinner     2               8.5
# 1.66    Sun4608       10.34     No   Sun  Dinner     3               3.4
# 3.50    Sun4458       21.01     No   Sun  Dinner     3               7.0
# 3.31    Sun5260       23.68     No   Sun  Dinner     2              11.8
# 3.61    Sun2251       24.59     No   Sun  Dinner     4               6.2
# ...         ...         ...    ...   ...     ...   ...               ...
# 5.92    Sat2657       29.03     No   Sat  Dinner     3               9.7
# 2.00    Sat1766       27.18    Yes   Sat  Dinner     2              13.6
# 2.00    Sat3880       22.67    Yes   Sat  Dinner     2              11.3
# 1.75      Sat17       17.82     No   Sat  Dinner     2               8.9
# 3.00    Thur672       18.78     No  Thur  Dinner     2               9.4
#
#               Payer Name         CC Number
# tip
# ...

# %%
df=pd.read_csv('tips.csv')

# %%
df=df.reset_index()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12096\3513803119.py in ?()
# ----> 1 df=df.reset_index()
#
# c:\Users\balaj\Desktop\QuantumCona\AIML_Practice\venv\lib\site-packages\pandas\core\frame.py in ?(self, level, drop, inplace, col_level, col_fill, allow_duplicates, names)
#    6490                     level_values = algorithms.take(
#    6491                         level_values, lab, allow_fill=True, fill_value=lev._na_value
#    6492                     )
#    6493
# -> 6494                 new_obj.insert(
#    6495                     0,
#    6496                     name,
#    6497                     level_values,
#
# c:\Users\balaj\Desktop\QuantumCona\AIML_Practice\venv\lib\site-packages\pandas\core\frame.py in ?(self, loc, column, value, allow_duplicates)
#    5176                 "'self.flags.allows_duplicate_labels' is False."
# ...

# %%
df.head()
# Out:
#    index  total_bill   tip     sex smoker  day    time  size  \
# 0      0       16.99  1.01  Female     No  Sun  Dinner     2
# 1      1       10.34  1.66    Male     No  Sun  Dinner     3
# 2      2       21.01  3.50    Male     No  Sun  Dinner     3
# 3      3       23.68  3.31    Male     No  Sun  Dinner     2
# 4      4       24.59  3.61  Female     No  Sun  Dinner     4
#
#    price_per_person          Payer Name         CC Number Payment ID
# 0              8.49  Christy Cunningham  3560325168603410    Sun2959
# 1              3.45      Douglas Tucker  4478071379779230    Sun4608
# 2              7.00      Travis Walters  6011812112971322    Sun4458
# 3             11.84    Nathaniel Harris  4676137647685994    Sun5260
# 4              6.15        Tonya Carter  4832732618637221    Sun2251

# %%
df=pd.read_csv('tips.csv')

# %%
df=df.set_index('Payment ID')

# %%
df
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# ...

# %%
#Retrieving Data Row based
#Index based
df.iloc[0]
# Out:
# index                                0
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %%
#Name based
df.loc['Sun2251']
# Out:
# index                              4
# total_bill                     24.59
# tip                             3.61
# sex                           Female
# smoker                            No
# day                              Sun
# time                          Dinner
# size                               4
# price_per_person                6.15
# Payer Name              Tonya Carter
# CC Number           4832732618637221
# Name: Sun2251, dtype: object

# %%
#Grabbing Multiple Rows
df.iloc[0:4]
# Out:
#             index  total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959         0       16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608         1       10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458         2       21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260         3       23.68  3.31    Male     No  Sun  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994

# %%
df.loc[['Sun2959','Sun5260']]
# Out:
#             index  total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959         0       16.99  1.01  Female     No  Sun  Dinner     2
# Sun5260         3       23.68  3.31    Male     No  Sun  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun5260                11.84    Nathaniel Harris  4676137647685994

# %%
df.head()
# Out:
#             index  total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959         0       16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608         1       10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458         2       21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260         3       23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251         4       24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221

# %%
#Removing the Row
df.drop('Sun2251',axis=0).head()
# Out:
#             index  total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959         0       16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608         1       10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458         2       21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260         3       23.68  3.31    Male     No  Sun  Dinner     2
# Sun9679         5       25.29  4.71    Male     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun9679                 6.32          Erik Smith   213140353657882

# %%
one_row=df.iloc[0]

# %%
one_row
# Out:
# index                                0
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %%
df.tail()
# Out:
#             index  total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sat2657       239       29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766       240       27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880       241       22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17         242       17.82  1.75    Male     No   Sat  Dinner     2
# Thur672       243       18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person       Payer Name         CC Number
# Payment ID
# Sat2657                 9.68    Michael Avila  5296068606052842
# Sat1766                13.59   Monica Sanders  3506806155565404
# Sat3880                11.34       Keith Wong  6011891618747196
# Sat17                   8.91     Dennis Dixon     4375220550950
# Thur672                 9.39  Michelle Hardin  3511451626698139

# %%
df = pd.concat([df, df.iloc[[0]]], ignore_index=True)

# %%
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
# 244       16.99  1.01  Female     No   Sun  Dinner     2              8.49
#
#              Payer Name         CC Number
# 240      Monica Sanders  3506806155565404
# 241          Keith Wong  6011891618747196
# 242        Dennis Dixon     4375220550950
# 243     Michelle Hardin  3511451626698139
# 244  Christy Cunningham  3560325168603410
